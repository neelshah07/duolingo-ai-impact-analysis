# %%
import sys

print(sys.executable)
# Out:
# c:\STUDY2\duolingo-ai-impact-analysis\.venv\Scripts\python.exe

# %%
from google_play_scraper import reviews
import pandas as pd

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %% [markdown]
# # AI Strategy Impact Analysis: Evaluating Duolingo's AI Transition
#
# ## Objective
#
# Collect user-generated data from multiple public sources to evaluate the impact of Duolingo's AI-first strategy on customer sentiment, retention risk, and business performance.
#
# ## Data Sources
#
# - Google Play Store Reviews
# - Reddit Discussions
# - AI Announcement Timeline
# - Financial Metrics (Later)

# %%
import pandas as pd
import numpy as np

from google_play_scraper import reviews

# %%
result, continuation_token = reviews(
    "com.duolingo",
    lang="en",
    country="us",
    count=10000
)

# %%
df = pd.DataFrame(result)

print("Shape:", df.shape)

df.head()
# Out:
# Shape: (10000, 11)
#                                reviewId       userName  \
# 0  931f4178-c5b4-4498-bbec-304695d46fc4  A Google user
# 1  4487a548-7643-452f-9464-397f3882d600  A Google user
# 2  e1371e19-7d63-4514-ac3e-9c28987db296  A Google user
# 3  6d6c02d8-bac1-4a23-93b5-81ca6ad88796  A Google user
# 4  5971a158-9761-4559-a4bd-17deb9fb800f  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                            perfect      5              0
# 1                                          very good      4              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              10000 non-null  str
#  1   userName              10000 non-null  str
#  2   userImage             10000 non-null  str
#  3   content               10000 non-null  str
#  4   score                 10000 non-null  int64
#  5   thumbsUpCount         10000 non-null  int64
#  6   reviewCreatedVersion  9241 non-null   str
#  7   at                    10000 non-null  datetime64[us]
#  8   replyContent          0 non-null      object
#  9   repliedAt             0 non-null      object
#  10  appVersion            9241 non-null   str
# dtypes: datetime64[us](1), int64(2), object(2), str(6)
# memory usage: 3.1+ MB

# %%
# Out:
# ['reviewId',
#  'userName',
#  'userImage',
#  'content',
#  'score',
#  'thumbsUpCount',
#  'reviewCreatedVersion',
#  'at',
#  'replyContent',
#  'repliedAt',
#  'appVersion']

# %%
df.to_csv(
    "../data/raw/google_play/duolingo_reviews.csv",
    index=False
)
